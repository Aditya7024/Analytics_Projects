# %% [markdown]
# # Online Gaming Behaviour/Pattern Recognition

# %% [markdown]
# This notebook contains the online gaming behaviour of individual players all over the world and some insight from them

# %% [markdown]
# **Importing all the necessary libries and modules.**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# For metrics and helpful functions
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# **Importing raw data as "online"**

# %%
# Importing raw data 
online = pd.read_csv("Raw_Data/online_gaming_behavior_dataset.csv")
#games = pd.read_csv("Raw_Data/games.csv")
computer = pd.read_csv("Raw_Data/computer_games.csv")

# %%
# printing first 5 rows of the data set
online.head()
# Out:
#    PlayerID  Age  Gender Location GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43    Male    Other  Strategy      16.271119                0
# 1      9001   29  Female      USA  Strategy       5.525961                0
# 2      9002   22  Female      USA    Sports       8.223755                0
# 3      9003   35    Male      USA    Action       5.265351                1
# 4      9004   33    Male   Europe    Action      15.531945                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    AchievementsUnlocked EngagementLevel
# 0                    25          Medium
# 1                    10          Medium
# 2                    41            High
# 3                    47          Medium
# 4                    37          Medium

# %% [markdown]
# # Cloumn details :
#
# `PlayerID`: Unique identifier for each player.
#
# `Age`: Age of the player.
#
# `Gender`: Gender of the player.
#
# `Location`: Geographic location of the player.
#
# `GameGenre`: Genre of the game the player is engaged in.
#
# `PlayTimeHours`: Average hours spent playing per session.
#
# `InGamePurchases`: Indicates whether the player makes in-game purchases (0 = No, 1 = Yes).
#
# `GameDifficulty`: Difficulty level of the game.
#
# `SessionsPerWeek`: Number of gaming sessions per week.
#
# `AvgSessionDurationMinutes`: Average duration of each gaming session in minutes.
#
# `PlayerLevel`: Current level of the player in the game.
#
# `AchievementsUnlocked`: Number of achievements unlocked by the player.
#
# `EngagementLevel`: Categorized engagement level reflecting player retention ('High', 'Medium', 'Low').

# %% [markdown]
# Created a function `basic_cl` for calculating and getting some insights from the data about the data, it includes build in functions like
#
# `info()`: Getting basic information about the columns
#
# `describe()`: Getting confidence interval(mean,median,standard deviation,count)
#
# `isna()`: Describe the number of null values
#
# `duplicated()`: Finds number of duplicate values from the columns
#
# `select_dtype(include = ['number']).colmns` Prints only numaric columns

# %%
def basic_cl(column_list):
    print("Information ",column_list.info(),"\n")
    print("\n ################################## \n")
    print("Describe ",column_list.describe(),"\n")
    print("\n ################################## \n")
    print("isnull ",column_list.isna().sum(),"\n")
    print("\n ################################## \n")
    print("Duplicates ",column_list.duplicated().sum(),"\n")
    print("\n ################################## \n")
    print("Numarical values columns only",column_list.select_dtypes(include = ["number"]).columns)

# %%
# passing the argument
basic_cl(online)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PlayerID                   40034 non-null  int64
#  1   Age                        40034 non-null  int64
#  2   Gender                     40034 non-null  object
#  3   Location                   40034 non-null  object
#  4   GameGenre                  40034 non-null  object
#  5   PlayTimeHours              40034 non-null  float64
#  6   InGamePurchases            40034 non-null  int64
#  7   GameDifficulty             40034 non-null  object
#  8   SessionsPerWeek            40034 non-null  int64
#  9   AvgSessionDurationMinutes  40034 non-null  int64
#  10  PlayerLevel                40034 non-null  int64
#  11  AchievementsUnlocked       40034 non-null  int64
#  12  EngagementLevel            40034 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 4.0+ MB
# Information  None
#
#
#  ##################################
#
# Describe             PlayerID           Age  PlayTimeHours  InGamePurchases  \
# count  40034.000000  40034.000000   40034.000000     40034.000000
# mean   29016.500000     31.992531      12.024365         0.200854
# std    11556.964675     10.043227       6.914638         0.400644
# min     9000.000000     15.000000       0.000115         0.000000
# 25%    19008.250000     23.000000       6.067501         0.000000
# 50%    29016.500000     32.000000      12.008002         0.000000
# 75%    39024.750000     41.000000      17.963831         0.000000
# max    49033.000000     49.000000      23.999592         1.000000
#
#        SessionsPerWeek  AvgSessionDurationMinutes   PlayerLevel  \
# count     40034.000000               40034.000000  40034.000000
# mean          9.471774                  94.792252     49.655568
# std           5.763667                  49.011375     28.588379
# min           0.000000                  10.000000      1.000000
# 25%           4.000000                  52.000000     25.000000
# 50%           9.000000                  95.000000     49.000000
# 75%          14.000000                 137.000000     74.000000
# max          19.000000                 179.000000     99.000000
#
#        AchievementsUnlocked
# count          40034.000000
# mean              24.526477
# std               14.430726
# min                0.000000
# 25%               12.000000
# 50%               25.000000
# 75%               37.000000
# max               49.000000
#
#
#  ##################################
#
# isnull  PlayerID                     0
# Age                          0
# Gender                       0
# Location                     0
# GameGenre                    0
# PlayTimeHours                0
# InGamePurchases              0
# GameDifficulty               0
# SessionsPerWeek              0
# AvgSessionDurationMinutes    0
# PlayerLevel                  0
# AchievementsUnlocked         0
# EngagementLevel              0
# dtype: int64
#
#
#  ##################################
#
# Duplicates  0
#
#
#  ##################################
#
# Numarical values columns only Index(['PlayerID', 'Age', 'PlayTimeHours', 'InGamePurchases',
#        'SessionsPerWeek', 'AvgSessionDurationMinutes', 'PlayerLevel',
#        'AchievementsUnlocked'],
#       dtype='object')

# %% [markdown]
# Define total no.of columns having "numeric" type

# %%
print(len(online.select_dtypes(include=["number"]).columns))
# Out:
# 8

# %% [markdown]
# Defined a function to calculate the number of **Outliers** from the over all columns

# %%
def graphs_an(csvfile):
    numeric_cols = csvfile.select_dtypes(include=["number"]).columns
    count = len(numeric_cols)
    
    # Define the number of rows and columns (half of the columns in each row)
    rows = 2
    cols = (count + 1) // 2  # Ensures enough columns for all plots

    # Create a figure with a grid layout
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 12))
    axes = axes.flatten()  # Flatten to easily iterate over all axes

    # Loop through each numeric column and create a boxplot
    for i, col in enumerate(numeric_cols):
        sns.boxplot(x=csvfile[col], orient='h', ax=axes[i])
        axes[i].set_title(f"Boxplot for {col}", fontsize=16)
    
    # represent the graph
    plt.tight_layout()
    plt.show()

# %%
# Usage example
graphs_an(online)

# %% [markdown]
# Now in order to conform wheather our data set have outliers or not we define another function with standard `1.5` factor

# %%
def find_outliers(column_list):
    for i in column_list:
        # assigning any value less then zero to zero
        online.loc[online[i] <= 0, i] = 0
        
        q1 = online[i].quantile(0.25)
        q3 = online[i].quantile(0.75)
        iqr = q3 - q1
        
        print("q1 value  ",q1,'\n',"q3 value  ",q3)

        upper_limit = q3 + (1.5 * iqr)  # finding highest and lowest limit
        lower_limit = q1 - (1.5 * iqr)

        print("upper limit value  ",upper_limit,'\n',"lower limit value  ",lower_limit)

        online.loc[online[i] > upper_limit,i] = upper_limit
        print(online[i].describe())

# %%
find_outliers(["PlayTimeHours"])
# Out:
# q1 value   6.067500507750126
#  q3 value   17.963831138295756
# upper limit value   35.8083270841142
#  lower limit value   -11.776995438068319
# count    40034.000000
# mean        12.024365
# std          6.914638
# min          0.000115
# 25%          6.067501
# 50%         12.008002
# 75%         17.963831
# max         23.999592
# Name: PlayTimeHours, dtype: float64

# %% [markdown]
# As we can see from the  above graphs that there are not much outliers in the data set which we conformed by applying each **numaric column** from the data set into the outlier function `find_outliers`.

# %%
pd.crosstab(online["SessionsPerWeek"], online["EngagementLevel"]).plot(kind ='bar',width = 0.8)
plt.title('Counts of playes by hours they played ')
plt.ylabel('playes count')
plt.xlabel('hours')
plt.show()

# %%
online["Gender"].value_counts()
# Out:
# Gender
# Male      23959
# Female    16075
# Name: count, dtype: int64

# %% [markdown]
# Getting more insights from the data and one of the column is `Gender` where we see
# **Male** - `23959`
#
# **Femal** - `16075`
# which shows that there are more number of male participants who are intrested in gaming more.
#
# Now we can proceed with our finding!

# %% [markdown]
# **Predictive modeling of player retention and engagement patterns.**
#
# Ho - Players spending more time effects engagment level
#
# H1 - Players spending less time does not effect engagment level

# %%
online2 = online.copy()
online2 = online2.drop(columns={"Location",})

# %%
# first for engagement level
online2["EngagementLevel"] = (
    online2["EngagementLevel"].astype("category")
    .cat.set_categories(["Low","Medium","High"])
    .cat.codes
)

# Second for game genre
online2["GameGenre"] = (
    online2["GameGenre"].astype("category")
    .cat.set_categories(["Sports", "Action", "Strategy", "Simulation", "RPG"])
    .cat.codes
)

# third for game difficulty
online2["GameDifficulty"] = (
    online2["GameDifficulty"].astype("category")
    .cat.set_categories(["Easy", "Medium", "High"])
    .cat.codes
)

# Fourth for gender
online2["Gender"] = (
    online2["Gender"].astype("category")
    .cat.set_categories(["Male","Female"])
    .cat.codes
)


online2 = pd.get_dummies(online2, drop_first= False)
online2.head()
# Out:
#    PlayerID  Age  Gender  GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43       0          2      16.271119                0
# 1      9001   29       1          2       5.525961                0
# 2      9002   22       1          0       8.223755                0
# 3      9003   35       0          1       5.265351                1
# 4      9004   33       0          1      15.531945                0
#
#    GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0               1                6                        108           79
# 1               1                5                        144           11
# 2               0               16                        142           35
# 3               0                9                         85           57
# 4               1                2                        131           95
#
#    AchievementsUnlocked  EngagementLevel
# 0                    25                1
# 1                    10                1
# 2                    41                2
# 3                    47                1
# 4                    37                1

# %%
# heat map
plt.figure(figsize=(16,9))
heatmap = sns.heatmap(online2.corr(),vmin=-1,vmax=1,annot=True,cmap=sns.color_palette("vlag",as_cmap=True))
heatmap.set_title("Coresponding Heat map ")
# Out:
# Text(0.5, 1.0, 'Coresponding Heat map ')

# %%
plt.figure(figsize=(8,6))
heatmap = sns.heatmap(online2[["EngagementLevel","PlayTimeHours","SessionsPerWeek","Age","GameDifficulty","AvgSessionDurationMinutes"]].corr(),annot=True,cmap="crest")
heatmap.set_title("Coresponding Heat map")
# Out:
# Text(0.5, 1.0, 'Coresponding Heat map')

# %%
 # finding average time a player have spend 
print("Average playtime per hour is  ",online2["PlayTimeHours"].mean())
print("Average sessions per week is  ",online2["SessionsPerWeek"].mean())
# Out:
# Average playtime per hour is   12.024365373325825
# Average sessions per week is   9.471773992106709

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(data = online2,x = "PlayTimeHours",y= "SessionsPerWeek",hue = "EngagementLevel",alpha = 0.4)
plt.axhline(y=9.471, color='#ff6361', label='9.471 hrs./week.', ls='--')
plt.legend(labels=["9.471 hrs./week", 'low', 'medium',"high"])
plt.title("sessions per week vs engagement level");

# %% [markdown]
# avg play time hour per session is 12 h/m and avg sessions per week in total is 9 so each player have to play at leat 2 hour 20 min(approx)(12/9) per session by the end of the week in order to increase the engagment level  .
#
# As you can observe that even though a person have spend 15-22 hours of play time but have session only 5-7 per week will have low engagment level . it might be the case that the player have completed bunch of sessions one day and gave a huge gape till next sessions.

# %%
y = online2["EngagementLevel"]
y.head()
# Out:
# 0    1
# 1    1
# 2    2
# 3    1
# 4    1
# Name: EngagementLevel, dtype: int8

# %%
X = online2.drop("EngagementLevel",axis = 1)
X.head()
# Out:
#    PlayerID  Age  Gender  GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43       0          2      16.271119                0
# 1      9001   29       1          2       5.525961                0
# 2      9002   22       1          0       8.223755                0
# 3      9003   35       0          1       5.265351                1
# 4      9004   33       0          1      15.531945                0
#
#    GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0               1                6                        108           79
# 1               1                5                        144           11
# 2               0               16                        142           35
# 3               0                9                         85           57
# 4               1                2                        131           95
#
#    AchievementsUnlocked
# 0                    25
# 1                    10
# 2                    41
# 3                    47
# 4                    37

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state=45)

# %%
log_cf = LogisticRegression(random_state=45, max_iter=500).fit(X_train,y_train)

# %%
y_pdic = log_cf.predict(X_test)

# %%
log_cunf = confusion_matrix(y_test,y_pdic, labels=log_cf.classes_)
log_dcunf = ConfusionMatrixDisplay(confusion_matrix=log_cunf, display_labels= log_cf.classes_)

log_dcunf.plot(values_format=" ")
plt.show()

# %%
online2["EngagementLevel"].value_counts(normalize=True)
# Out:
# EngagementLevel
# 1    0.483939
# 2    0.258181
# 0    0.257881
# Name: proportion, dtype: float64

# %%
target_names = ['At Low Engagement level','At Medium Engagement level','At High Engagement level']
print(classification_report(y_test,y_pdic))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.59      0.67      2599
#            1       0.67      0.77      0.72      4851
#            2       0.67      0.63      0.65      2559
#
#     accuracy                           0.69     10009
#    macro avg       0.70      0.66      0.68     10009
# weighted avg       0.69      0.69      0.69     10009

# %% [markdown]
# **Analysis of factors influencing player behavior and game performance.**

# %%
pd.crosstab(online['GameDifficulty'], online['EngagementLevel']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='GameDifficulty'>

# %%
fig,ax = plt.subplots(1,2,figsize = (22,8))

sns.countplot(x='GameGenre', hue='Gender', data=online, ax = ax[0])
ax[0].set_title("Game Genre played by Gender",fontsize = 14)

sns.countplot(data=online, x = 'GameGenre', hue="GameDifficulty", ax=ax[1])
ax[1].set_title("Determine most played game by defficulty levels", fontsize = 14)

plt.show();

# %%
online["InGamePurchases"].value_counts(normalize=True)
# Out:
# InGamePurchases
# 0    0.799146
# 1    0.200854
# Name: proportion, dtype: float64

# %%
sns.barplot(data=online,x = 'GameGenre', y ="InGamePurchases", hue="GameDifficulty",palette="muted")
plt.axhline(y = 0.20, color='red', linestyle='--')
plt.show();

# %%
fig,ax = plt.subplots(1,2,figsize= (22,8))

sns.countplot(x= online["InGamePurchases"],hue = online["AchievementsUnlocked"],ax=ax[0])
ax[0].set_title("achivement by in game purchases")

sns.countplot(x = online["Age"],hue=online["InGamePurchases"],ax=ax[1])
ax[1].set_title("achivement by age ")

plt.show();

# %%
online["Age"].mean()
# Out:
# np.float64(31.9925313483539)
